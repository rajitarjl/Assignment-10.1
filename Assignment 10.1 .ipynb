# %%
# Import package
from urllib.request import urlretrieve

# Import pandas
import pandas as pd

# Assign url of file: url
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv'

# Save file locally
urlretrieve(url, 'us_baby_names.csv')

# Read file into a DataFrame and print its head
df = pd.read_csv('us_baby_names.csv', sep=',')
print(df.head())
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
# 1 Delete unnamed columns
del df['Unnamed: 0']
print(df.head())
# Out:
#       Id     Name  Year Gender State  Count
# 0  11350     Emma  2004      F    AK     62
# 1  11351  Madison  2004      F    AK     48
# 2  11352   Hannah  2004      F    AK     46
# 3  11353    Grace  2004      F    AK     44
# 4  11354    Emily  2004      F    AK     41

# %%
# 2 Show the distribution of male and female
df['Gender'].value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %%
# 3 Show the top 5 most preferred names
df.groupby("Name").sum()
df.head()
# Out:
#       Id     Name  Year Gender State  Count
# 0  11350     Emma  2004      F    AK     62
# 1  11351  Madison  2004      F    AK     48
# 2  11352   Hannah  2004      F    AK     46
# 3  11353    Grace  2004      F    AK     44
# 4  11354    Emily  2004      F    AK     41

# %%
# Problem : 4. What is the median name occurence in the dataset

# group the data
names = df.groupby("Name").sum()

# print the first 5 observations
names.head()

# print the size of the dataset
print("Size :", names.shape)

# sort it from the biggest value to the smallest one
names.sort_values("Count", ascending = 0).head()
# Out:
# Size : (17632, 3)
#                   Id     Year   Count
# Name
# Jacob     1665681356  1141099  242874
# Emma      1629482250  1137085  214852
# Michael   1687521295  1161152  214405
# Ethan     1660808475  1139091  209277
# Isabella  1630131786  1137090  204798

# %%
4. What is the median name occurence in the dataset
names[names.Count == names.Count.median()]
# Out:
#   File "<ipython-input-7-137dcf12d2f8>", line 1
#     4. What is the median name occurence in the dataset
#           ^
# SyntaxError: invalid syntax

# %%
# Problem : 5. Distribution of male and female born count by states

#df.head()
df.groupby(['Gender','State']).sum()
# Out:
#                         Id      Year    Count
# Gender State
# F      AK         30173806   4829869    26250
#        AL        890822735  19845311   215308
#        AR       1446562804  14406855   129712
#        AZ       4391847439  29165718   368567
#        CA      24509016180  90692449  2414063
#        CO       8682268560  22951166   260805
#        CT       5586816950  13208966   141350
#        DC       2788237734   6133657    35276
#        DE       2434453038   5120947    31312
#        FL      27430623066  51794371   915422
#        GA      24057133930  38943789   549637
#        HI       4403998725   6539042    37279
#        IA      10156854444  14326801   144764
#        ID       7342414165   9880236    72808
#        IL      34754283382  42726564   695312
#        IN      23535261312  26230110   344962
#        KS      14806586364  15576162   147216
#        KY      17726446245  17713738   210201
#        LA      22440873175  21115527   221859
# ...
